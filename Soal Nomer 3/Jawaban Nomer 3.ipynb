# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from apyori import apriori

# %%
data = pd.read_excel('D:/Aminurachma Aisyah Nilatika/STIMATA/Semester 6/Data Mining/UAS/datamining/Uas/dataset_soal No. 3.xls',header = None)

# %%
data.head()
# Out:
#                0                  1             2                  3  \
# 0          Item1              Item2         Item3              Item4
# 1        burgers          meatballs          eggs     low fat yogurt
# 2        chutney     low fat yogurt           NaN  whole wheat pasta
# 3         turkey  whole wheat pasta  french fries               soup
# 4  mineral water               soup   light cream  frozen vegetables
#
#               4              5       6                  7             8  \
# 0         Item5          Item6   Item7              Item8         Item9
# 1           NaN  mineral water  salmon     low fat yogurt           NaN
# 2  french fries  mineral water  salmon  whole wheat pasta  french fries
# 3   light cream        shallot     NaN               soup   light cream
# 4     spaghetti      green tea     NaN  frozen vegetables     spaghetti
#
#                9
# 0         Item10
# 1  mineral water
# 2  mineral water
# 3        shallot
# 4      green tea

# %%
data.shape
# Out:
# (2055, 10)

# %%
records = []
for i in range(0, 2055):
    records.append([str(data.values[i,j]) for j in range(0, 10)])

# %%
association_rules = apriori(records, min_support=0.2, min_confidence=0.2, min_lift=0.2, min_length=2)
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 61

# %%
association_results[0]
# Out:
# RelationRecord(items=frozenset({'avocado'}), support=0.3143552311435523, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'avocado'}), confidence=0.3143552311435523, lift=1.0)])

# %%
results = []
for item in association_results:
    pair = item[0]
    items = [x for x in pair]
    
    value0 = str(items[0])
    value2 = str(item[1])[:10]
    value3 = str(item[2][0][2])[:10]
    value4 = str(item[2][0][3])[:10]
    
    rows = (value0, value2, value3, value4)
    
    results.append(rows)
    
    label = ['Title1'],['Support'], ['Confidence'],['Lift']
    print("===============================================================")
    
    store_suggestion = pd.DataFrame.from_records(results,columns=label)
    
    print(store_suggestion)
# Out:
# ...
#   (Title1,)  (Support,) (Confidence,) (Lift,)
# 0   avocado  0.31435523    0.31435523     1.0
# ...
#   (Title1,)  (Support,) (Confidence,) (Lift,)
# 0   avocado  0.31435523    0.31435523     1.0
# 1   burgers  0.24282238    0.24282238     1.0
# ...
#    (Title1,)  (Support,) (Confidence,) (Lift,)
# 0    avocado  0.31435523    0.31435523     1.0
# 1    burgers  0.24282238    0.24282238     1.0
# 2  chocolate  0.47542579    0.47542579     1.0
# ...
#              (Title1,)  (Support,) (Confidence,) (Lift,)
# 0              avocado  0.31435523    0.31435523     1.0
# 1              burgers  0.24282238    0.24282238     1.0
# 2            chocolate  0.47542579    0.47542579     1.0
# 3  clothes accessories  0.33965936    0.33965936     1.0
# ...
#              (Title1,)  (Support,) (Confidence,) (Lift,)
# 0              avocado  0.31435523    0.31435523     1.0
# 1              burgers  0.24282238    0.24282238     1.0
# 2            chocolate  0.47542579    0.47542579     1.0
# ...

# %%
store_suggestion.describe()
# Out:
#        (Title1,)  (Support,) (Confidence,) (Lift,)
# count         61          61            61      61
# unique        15          53            53       1
# top          nan  0.24294060    0.24294060     1.0
# freq          14           4             4      61

# %%
store_suggestion.to_excel('C:/Users/Aminurachma Aisyah/Outputs_AR_Nomer3.xls')
